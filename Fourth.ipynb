# %%
a=2
b=4
c=6
if (a==2) and (b<a) and (c>a): # when all condition will be true, if blocks will work because of logical "and" operator.
  a=a+1 #2+1
  print(a) #3
else:
  b=b-2
  print(b)
# Out:
# 2

# %%
marks=int(input("Enter Student marks: "))
if marks > 80: # 72>80 ----> F
  print('Grade A')
elif marks > 70: # 72>70---> T
  print("Grade B")
elif marks > 60:
  print("Grade C")
else:
  print("print D")
# Out:
# Enter Student marks: 65
# Grade C

# %%
marks=int(input("Enter Student marks: "))
if marks > 80: #82>80
  print("Grade A")
  if marks <  85: # 82<85    Nested if
    print("50% school fee off")
  elif marks > 85: # 82>85
    print("100% school fee off")
else:
  print("Good Grades, only certificate")
# Out:
# Enter Student marks: 72
# Good Grades, only certificate
