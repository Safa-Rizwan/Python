# %%
#print(3<9) ----> less than
#print(4==6) ----> equality
#print(4!=6) # not equals
#print(5>2) # ----> greater 
a=4
b=7
#print(a<b) # ----(4<7) ----> True
#print(b>a) #---(7>4) ----> True
#print(a==b)
#print(a!=b) 
#print(a!=4)
#var1="apple" #----> 97
#var2="Apple" # ---> 65
#print(var1<var2)

x= True
y= False
print(x or y) #(1 + 0) 
print(x and y) #(1 x 0)
# Out:
# True
# False

# %%
a=5
b=6
#if a>b:
 # print("Hello World")
#else:
 # print("b is greater")

if a==a:
  print("Condition is True")
else:
  print("Condition is false")
# Out:
# Condition is True
