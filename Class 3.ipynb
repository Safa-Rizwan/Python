# %% [markdown]
# range(starting,ending-1,step)
#
# syntax:
# for variable name in range(starting,ending+1,stepsize):
#
#
# ```
# # This is formatted as code
# ```

# %%
for i in range(1,11,1):
  if i == 2:
    continue
  print(i)
# Out:
# 1
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
