# %% [markdown]
# Loops:
# Types: 2
# 1- While loop
# 2- For Loop

# %%
print("Aliyaan")
print("Aliyaan")
print(1)
print(2)
# Out:
# Aliyaan

# %% [markdown]
# While Loop
# variable declaration ----> starting point
# condition in loop
# increment 0r decrement

# %%
i = 10 # variable declaration
while i > 10: # condition
  print(i,"Aliyaan")
  i-=1 # decrement in variable value
else:
  print("Condition goes false")
# Out:
# Condition goes false

# %%
#count = 1
#while count < 100:
 # print(count)
  #count+=1

#Test: 01
#fruit = input("Enter a fruit name:") # user value 
#if fruit == "apple":
 # print("You won")
#else:
 # print("you lost")
# test : 02

# test : 03

#value = int(input("enter a value:")) # "20"
#count = 1
#while count<value:
 # print(count)
  #if count == 50:
   # break  
  #count+=1

table=int(input("Enter a number for table:")) #user input
i =1
while i<21:
  #print(i)
  print( table,"x",i, "=",table*i)
  i+=1
# Out:
# Enter a number for table:5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# 5 x 11 = 55
# 5 x 12 = 60
# 5 x 13 = 65
# 5 x 14 = 70
# 5 x 15 = 75
# 5 x 16 = 80
# 5 x 17 = 85
# 5 x 18 = 90
# 5 x 19 = 95
# 5 x 20 = 100
